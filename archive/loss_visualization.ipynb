# %%
import numpy as np
import pandas as pd

# %%
loss_data = np.load('E:\Shahmir\SpaceNET 7\\archive\Loss History\\att_generator_loss_val.npy')

# %%
loss_df = pd.DataFrame(loss_data)
loss_df.columns = ['Loss']

# %%
loss_df.min()
# Out:
# Loss    0.027869
# dtype: float64

# %%
loss_df.plot()
# Out:
# <Axes: >
